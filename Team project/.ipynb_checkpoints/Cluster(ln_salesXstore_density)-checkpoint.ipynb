# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
hangjungdong_sales = pd.read_csv('C:\TIL\Team project/행정동별_DB.csv')

# %%
hangjungdong_sales
# Out:
#       Unnamed: 0    행정동_코드  기준_년_코드  기준_분기_코드   분기당_매출_금액  분기당_매출_건수  점포수  \
# 0              0  11110515     2019         1  4675790356     237169  305
# 1              1  11110515     2019         2  4826602913     288328  280
# 2              2  11110515     2019         3  5054226611     294296  306
# 3              3  11110515     2019         4  5259740378     276138  296
# 4              4  11110515     2020         1  3831066308     201207  280
# ...          ...       ...      ...       ...         ...        ...  ...
# 5996        5996  11740700     2021         3  5268468421     286646  284
# 5997        5997  11740700     2021         4  5055977570     246028  267
# 5998        5998  11740700     2022         1  4458386133     224449  161
# 5999        5999  11740700     2022         2  5527855722     266771  163
# 6000        6000  11740700     2022         3  5740889583     271136  161
#
#       면적 (k㎡)   건당_매출액  점포_밀집도
# 0        2.57  23701.0   118.0
# ...

# %%
# 4분기 제외 (2022YQ3까지만 있는 관계로 매년 ~Q3 데이터까지만 활용)
hangjungdong_sales.drop(hangjungdong_sales[hangjungdong_sales['기준_분기_코드'] ==4].index)
# Out:
#       Unnamed: 0    행정동_코드  기준_년_코드  기준_분기_코드   분기당_매출_금액  분기당_매출_건수  점포수  \
# 0              0  11110515     2019         1  4675790356     237169  305
# 1              1  11110515     2019         2  4826602913     288328  280
# 2              2  11110515     2019         3  5054226611     294296  306
# 4              4  11110515     2020         1  3831066308     201207  280
# 5              5  11110515     2020         2  4730870452     263071  283
# ...          ...       ...      ...       ...         ...        ...  ...
# 5995        5995  11740700     2021         2  5516378578     286822  291
# 5996        5996  11740700     2021         3  5268468421     286646  284
# 5998        5998  11740700     2022         1  4458386133     224449  161
# 5999        5999  11740700     2022         2  5527855722     266771  163
# 6000        6000  11740700     2022         3  5740889583     271136  161
#
#       면적 (k㎡)   건당_매출액  점포_밀집도
# 0        2.57  23701.0   118.0
# ...

# %%
hangjungdong_sales_ = hangjungdong_sales.groupby(['행정동_코드','기준_년_코드']).agg({'분기당_매출_금액':sum, '분기당_매출_건수':sum,'점포수' : np.average, "면적 (k㎡)":max,"점포_밀집도":np.average }).reset_index()

# %%
hangjungdong_sales_
# Out:
#         행정동_코드  기준_년_코드     분기당_매출_금액  분기당_매출_건수          점포수  면적 (k㎡)  \
# 0     11110515     2019   19816360258    1095931   296.750000     2.57
# 1     11110515     2020   18089079791     935274   283.000000     2.57
# 2     11110515     2021   25083059412    1297556   285.250000     2.57
# 3     11110515     2022   25734795800    1345940   157.666667     2.57
# 4     11110530     2019  309346012700   13513402  2355.250000     1.23
# ...        ...      ...           ...        ...          ...      ...
# 1596  11740685     2022   87037961471    4886490   705.333333     1.61
# 1597  11740700     2019   25367953678    1215827   320.750000     1.56
# 1598  11740700     2020   23735340525    1236250   317.500000     1.56
# 1599  11740700     2021   20667046819    1064359   286.500000     1.56
# 1600  11740700     2022   15727131438     762356   161.666667     1.56
#
#            점포_밀집도
# 0      115.500000
# 1      110.000000
# 2      111.000000
# 3       61.000000
# ...

# %%
hangjungdong_sales_['ln_매출_금액'] = np.log(hangjungdong_sales_['분기당_매출_금액'])

# %%
hangjungdong_sales_
# Out:
#         행정동_코드  기준_년_코드     분기당_매출_금액  분기당_매출_건수          점포수  면적 (k㎡)  \
# 0     11110515     2019   19816360258    1095931   296.750000     2.57
# 1     11110515     2020   18089079791     935274   283.000000     2.57
# 2     11110515     2021   25083059412    1297556   285.250000     2.57
# 3     11110515     2022   25734795800    1345940   157.666667     2.57
# 4     11110530     2019  309346012700   13513402  2355.250000     1.23
# ...        ...      ...           ...        ...          ...      ...
# 1596  11740685     2022   87037961471    4886490   705.333333     1.61
# 1597  11740700     2019   25367953678    1215827   320.750000     1.56
# 1598  11740700     2020   23735340525    1236250   317.500000     1.56
# 1599  11740700     2021   20667046819    1064359   286.500000     1.56
# 1600  11740700     2022   15727131438     762356   161.666667     1.56
#
#            점포_밀집도   ln_매출_금액
# 0      115.500000  23.709774
# 1      110.000000  23.618574
# ...

# %%
for_cluster = hangjungdong_sales_[[ '행정동_코드', '기준_년_코드','ln_매출_금액', '점포_밀집도']]

# %%
for_cluster.rename(columns={'행정동_코드':'code',
                                    '기준_년_코드':'year',
                                    'ln_매출_금액':'sales',
                                    '점포_밀집도': 'store density'}, inplace=True)
# Out:
# C:\Users\이화정\AppData\Local\Temp\ipykernel_28304\2997789160.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for_cluster.rename(columns={'행정동_코드':'code',

# %%
for_cluster
# Out:
#           code  year      sales  store density
# 0     11110515  2019  23.709774     115.500000
# 1     11110515  2020  23.618574     110.000000
# 2     11110515  2021  23.945459     111.000000
# 3     11110515  2022  23.971110      61.000000
# 4     11110530  2019  26.457726    1914.500000
# ...        ...   ...        ...            ...
# 1596  11740685  2022  25.189610     438.000000
# 1597  11740700  2019  23.956753     206.000000
# 1598  11740700  2020  23.890231     203.500000
# 1599  11740700  2021  23.751806     183.250000
# 1600  11740700  2022  23.478653     104.333333
#
# [1601 rows x 4 columns]

# %%
for_cluster19 = for_cluster[for_cluster['year'] == 2019]
for_cluster20 = for_cluster[for_cluster['year'] == 2020]
for_cluster21 = for_cluster[for_cluster['year'] == 2021]
for_cluster22 = for_cluster[for_cluster['year'] == 2022]

# %%
# 데이터 정규화(Min-Max)
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
scaler.fit(for_cluster19[['sales','store density']])
scaler.fit(for_cluster20[['sales','store density']])
scaler.fit(for_cluster21[['sales','store density']])
scaler.fit(for_cluster22[['sales','store density']])
# Out:
# MinMaxScaler()

# %%
set_19_sc = scaler.transform(for_cluster19[['sales','store density']])
set_20_sc = scaler.transform(for_cluster20[['sales','store density']])
set_21_sc = scaler.transform(for_cluster21[['sales','store density']])
set_22_sc = scaler.transform(for_cluster22[['sales','store density']])

# %%
# !pip install yellowbrick

# %%
# 적절한 군집수 찾기 1. The Elbow method
from yellowbrick.cluster import KElbowVisualizer

# %%
# 2019년
model = KMeans(random_state=0)
visualizer = KElbowVisualizer(model, k = (1,10))
plt.subplot(2, 1, 1)
visualizer.fit(set_19_sc.reshape(-1,1))

# 2020년
model = KMeans(random_state=0)
visualizer = KElbowVisualizer(model, k = (1,10))
plt.subplot(2, 1, 2)
visualizer.fit(set_20_sc.reshape(-1,1))
# Out:
# KElbowVisualizer(ax=<AxesSubplot:>,
#                  estimator=KMeans(n_clusters=9, random_state=0), k=(1, 10))

# %%
# 2021년
model = KMeans(random_state=0)
visualizer = KElbowVisualizer(model, k = (1,10))
plt.subplot(2, 1, 1)
visualizer.fit(set_21_sc.reshape(-1,1))

# 2022년
model = KMeans(random_state=0)
visualizer = KElbowVisualizer(model, k = (1,10))
plt.subplot(2, 1, 2)
visualizer.fit(set_22_sc.reshape(-1,1))
# Out:
# KElbowVisualizer(ax=<AxesSubplot:>,
#                  estimator=KMeans(n_clusters=9, random_state=0), k=(1, 10))

# %%
# 적절한 군집수 찾기 2. The Silhouette method
### 여러개의 클러스터링 갯수를 List로 입력 받아 각각의 실루엣 계수를 면적으로 시각화한 함수 작성
def visualize_silhouette(cluster_lists, X_features): 
    
    # from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math
    
    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)
    
    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)
    
    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):
        
        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)
        
        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)
        
        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
        
        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()
            
            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i
            
            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10
            
        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
# 2019년
# cluster 개수를 3개, 4개, 5개, 6개 일때의 클러스터별 실루엣 계수 평균값을 시각화 
visualize_silhouette([2, 3, 4, 5], set_19_sc)

# %%
# 2020년
# cluster 개수를 3개, 4개, 5개, 6개 일때의 클러스터별 실루엣 계수 평균값을 시각화 
visualize_silhouette([2, 3, 4, 5], set_20_sc)

# %%
# 2021년
# cluster 개수를 3개, 4개, 5개, 6개 일때의 클러스터별 실루엣 계수 평균값을 시각화 
visualize_silhouette([2, 3, 4, 5], set_21_sc)

# %%
# 2022년
# cluster 개수를 3개, 4개, 5개, 6개 일때의 클러스터별 실루엣 계수 평균값을 시각화 
visualize_silhouette([2, 3, 4, 5], set_22_sc)

# %%
# 군집 수 적용
km19 = KMeans(n_clusters=4, init='k-means++', random_state=119).fit(set_19_sc)
km20 = KMeans(n_clusters=4, init='k-means++', random_state=119).fit(set_20_sc)
km21 = KMeans(n_clusters=4, init='k-means++', random_state=119).fit(set_21_sc)
km22 = KMeans(n_clusters=4, init='k-means++', random_state=119).fit(set_22_sc)

# %%
for_cluster19['cluster'] = km19.predict(set_19_sc)
for_cluster20['cluster'] = km20.predict(set_20_sc)
for_cluster21['cluster'] = km22.predict(set_21_sc)
for_cluster22['cluster'] = km22.predict(set_22_sc)
# Out:
# C:\Users\이화정\AppData\Local\Temp\ipykernel_28304\268568640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for_cluster19['cluster'] = km19.predict(set_19_sc)
# C:\Users\이화정\AppData\Local\Temp\ipykernel_28304\268568640.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for_cluster20['cluster'] = km20.predict(set_20_sc)
# C:\Users\이화정\AppData\Local\Temp\ipykernel_28304\268568640.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# 19, 20년 군집 번호 변경 
new_for_cluster19 = for_cluster19.copy()
new_for_cluster20 = for_cluster20.copy()
new_for_cluster21 = for_cluster21.copy()
new_for_cluster22 = for_cluster22.copy()

# %%
# 군집 변경 함수
# 2019년 
## 0번 군집 -> 2번 군집  
## 2번 군집 -> 3번 군집
## 3번 군집 -> 0번 군집  

def change_num_2019(num) :
        if num == 0:
            return 2
        elif num == 2:
            return 3
        elif num == 3:
            return 0
        else : return num
        
# 2020년 
## 0번 군집 -> 2번 군집
## 2번 군집 -> 0번 군집 

def change_num_2020(num) :
        if num == 0:
            return 2
        elif num == 2 :
            return 0 
        else : return num
        
# 2021년, 2022년
## 1번 군집 -> 2번 군집
## 2번 군집 -> 3번 군집 
## 3번 군집 -> 1번 군집 

def change_num_2122(num) :
        if num == 1:
            return 2
        elif num == 2:
            return 3
        elif num == 3:
            return 1
        else : return num

# %%
new_for_cluster19['cluster'] = new_for_cluster19['cluster'].apply(change_num_2019 )

new_for_cluster19['cluster'].value_counts()
# Out:
# 1    216
# 0     93
# 2     77
# 3     15
# Name: cluster, dtype: int64

# %%
new_for_cluster20['cluster'] = new_for_cluster20['cluster'].apply(change_num_2020)

new_for_cluster20['cluster'].value_counts()
# Out:
# 1    209
# 2     86
# 0     85
# 3     20
# Name: cluster, dtype: int64

# %%
new_for_cluster21['cluster'] = new_for_cluster21['cluster'].apply(change_num_2122)
new_for_cluster22['cluster'] = new_for_cluster22['cluster'].apply(change_num_2122)

# %%
print(f'2019년도 군집:\n', new_for_cluster19['cluster'].value_counts())
print(f'\n2020년도 군집:\n', new_for_cluster20['cluster'].value_counts())
print(f'\n2021년도 군집:\n', new_for_cluster21['cluster'].value_counts())
print(f'\n2022년도 군집:\n', new_for_cluster22['cluster'].value_counts())
# Out:
# 2019년도 군집:
#  1    216
# 0     93
# 2     77
# 3     15
# Name: cluster, dtype: int64
#
# 2020년도 군집:
#  1    209
# 2     86
# 0     85
# 3     20
# Name: cluster, dtype: int64
#
# 2021년도 군집:
#  1    165
# 2    137
# 3     51
# 0     47
# Name: cluster, dtype: int64
#
# 2022년도 군집:
#  1    202
# 2    121
# 0     60
# 3     17
# Name: cluster, dtype: int64

# %%
c_19 = new_for_cluster19.drop(['year', 'code'], axis=1)
c_20 = new_for_cluster20.drop(['year', 'code'], axis=1)
c_21 = new_for_cluster21.drop(['year', 'code'], axis=1)
c_22 = new_for_cluster22.drop(['year', 'code'], axis=1)

# %%
# (x, y) = (건당 매출 금액, 점포 밀집도) 시각화 
# 2019년
sct_2019 = sns.scatterplot(x='sales', y='store density', hue='cluster', data=c_19)
sct_2019.set(title = "2019Y")
# Out:
# [Text(0.5, 1.0, '2019Y')]

# %%
# 2020년
sct_2020 = sns.scatterplot(x='sales', y='store density', hue='cluster', data=c_20)
sct_2020.set(title = "2020Y")
# Out:
# [Text(0.5, 1.0, '2020Y')]

# %%
# 2021년
sct_2021 = sns.scatterplot(x='sales', y='store density', hue='cluster', data=c_21)
sct_2021.set(title = "2021Y")
# Out:
# [Text(0.5, 1.0, '2021Y')]

# %%
# 2022년
sct_2022 = sns.scatterplot(x='sales', y='store density', hue='cluster', data=c_22)
sct_2022.set(title = "2022Y")
# Out:
# [Text(0.5, 1.0, '2022Y')]

# %%
# 변수간 산점도 시각화 (pairplot: 데이터에 들어 있는 각 컬럼(열)들의 모든 상관 관계를 출력)
# 2019Y
sns.pairplot(c_19, hue = 'cluster')
plt.show()

# %%
# 2020Y
sns.pairplot(c_20, hue = 'cluster')
plt.show()

# %%
# 2021Y
sns.pairplot(c_21, hue = 'cluster')
plt.show()

# %%
# 2022Y 
sns.pairplot(c_22, hue = 'cluster')
plt.show()

# %%
# 연도별 군집별 요약 통계 

# 2019년

print(c_19.describe())
c_19_des = new_for_cluster19.groupby(by='cluster')['sales', 'store density'].describe().T
# Out:
#             sales  store density     cluster
# count  401.000000     401.000000  401.000000
# mean    24.043914     526.234206    1.034913
# std      1.464032     568.473819    0.757481
# min     15.357704       1.250000    0.000000
# 25%     23.341692     165.250000    1.000000
# 50%     24.075266     353.750000    1.000000
# 75%     24.954647     680.250000    1.000000
# max     27.601204    3961.750000    3.000000
# C:\Users\이화정\AppData\Local\Temp\ipykernel_28304\1531558037.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   c_19_des = new_for_cluster19.groupby(by='cluster')['sales', 'store density'].describe().T

# %%
# 2020년

print(c_20.describe())
c_20_des = new_for_cluster20.groupby(by='cluster')['sales', 'store density'].describe().T
# Out:
#             sales  store density     cluster
# count  400.000000     400.000000  400.000000
# mean    23.958974     529.498750    1.102500
# std      1.362557     573.177259    0.786473
# min     17.239189       2.250000    0.000000
# 25%     23.278393     166.125000    1.000000
# 50%     24.002514     359.125000    1.000000
# 75%     24.835491     680.187500    2.000000
# max     27.312835    3967.750000    3.000000
# C:\Users\이화정\AppData\Local\Temp\ipykernel_28304\670296676.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   c_20_des = new_for_cluster20.groupby(by='cluster')['sales', 'store density'].describe().T

# %%
# 2021년

print(c_21.describe())
c_21_des = new_for_cluster21.groupby(by='cluster')['sales', 'store density'].describe().T
# Out:
#             sales  store density     cluster
# count  400.000000     400.000000  400.000000
# mean    23.879200     511.090000    1.480000
# std      1.360552     544.991708    0.861077
# min     18.082426       2.750000    0.000000
# 25%     23.188196     164.125000    1.000000
# 50%     23.871247     348.250000    1.000000
# 75%     24.760968     667.000000    2.000000
# max     27.257173    3763.750000    3.000000
# C:\Users\이화정\AppData\Local\Temp\ipykernel_28304\971092142.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   c_21_des = new_for_cluster21.groupby(by='cluster')['sales', 'store density'].describe().T

# %%
# 2022년

print(c_22.describe())
c_22_des = new_for_cluster22.groupby(by='cluster')['sales', 'store density'].describe().T
# Out:
#             sales  store density     cluster
# count  400.000000     400.000000  400.000000
# mean    23.706891     280.941667    1.237500
# std      1.413538     327.763855    0.753334
# min     17.516408       0.000000    0.000000
# 25%     22.973195      82.916667    1.000000
# 50%     23.698353     187.000000    1.000000
# 75%     24.639304     360.583333    2.000000
# max     27.220229    2534.333333    3.000000
# C:\Users\이화정\AppData\Local\Temp\ipykernel_28304\925741542.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   c_22_des = new_for_cluster22.groupby(by='cluster')['sales', 'store density'].describe().T

# %%
c_year_all = pd.concat([c_19_des, c_20_des, c_21_des, c_22_des], axis=1)

# %%
c_year_all[0]
# 2019년도 대비 2022년 평균 점포 밀집도가 약 66%나 감소한 군집임 
# 반면 평균 ln(sales)는 2019년도에 비해 0.8%p 감소 
# -> 평균 점포 밀집도 및 평균 ln(sales)가 가장 크게 감소한 군집
# Out:
# cluster                       0           0           0           0
# sales         count   93.000000   85.000000   47.000000   60.000000
#               mean    22.153445   22.059685   21.367568   21.349423
#               std      1.255681    0.983409    0.860049    0.945379
#               min     15.357704   17.239189   18.082426   17.516408
#               25%     21.631587   21.433239   20.756804   20.643937
#               50%     22.550057   22.336599   21.418602   21.620176
#               75%     22.917088   22.837132   22.093259   22.091510
#               max     23.486973   23.192840   22.455299   22.413351
# store density count   93.000000   85.000000   47.000000   60.000000
#               mean   113.531362  110.805882   55.813830   38.933333
#               std     86.028949   86.764060   43.139261   36.814330
#               min      1.250000    2.250000    2.750000    0.000000
#               25%     38.000000   36.750000   23.250000   14.250000
# ...

# %%
c_year_all[1]
# 2019년도 대비 2022년 평균 점포 밀집도가 약 57% 감소한 군집임
# 평균 ln(sales)는 2019년도에 비해 0.8%p 감소
# Out:
# cluster                       1           1           1           1
# sales         count  216.000000  209.000000  165.000000  202.000000
#               mean    24.242954   24.073171   23.408991   23.456227
#               std      0.719325    0.695969    0.498089    0.512467
#               min     22.933836   22.845394   22.334405   22.435764
#               25%     23.689370   23.562013   23.035905   23.093574
#               50%     24.135448   23.918637   23.457857   23.474450
#               75%     24.590724   24.444779   23.720586   23.812563
#               max     27.041725   27.024829   24.713654   24.534438
# store density count  216.000000  209.000000  165.000000  202.000000
#               mean   364.082176  334.174641  234.737879  157.821782
#               std    181.263410  167.248464  127.739746   92.930314
#               min      6.250000    7.000000    3.750000    4.000000
#               25%    234.437500  208.750000  136.250000   89.833333
# ...

# %%
c_year_all[2]
# 2019년도 대비 2022년 평균 점포 밀집도가 약 59% 감소한 군집임
# 평균 ln(sales)는 2019년도에 비해 0.3%p 감소 -> 가장 적게 감소한 군집
# Out:
# cluster                        2            2            2           2
# sales         count    77.000000    86.000000   137.000000  121.000000
#               mean     25.249425    25.001642    24.680267   24.928483
#               std       0.694656     0.636226     0.669786    0.606491
#               min      23.507158    23.305228    23.193436   23.463624
#               25%      24.900616    24.638003    24.195185   24.534743
#               50%      25.209744    25.018559    24.640351   24.841173
#               75%      25.722560    25.427803    25.041163   25.293786
#               max      27.098667    26.715201    27.043151   26.856220
# store density count    77.000000    86.000000   137.000000  121.000000
#               mean   1076.090909   982.921512   576.883212  443.498623
#               std     293.881057   267.868891   215.661382  191.485935
#               min     676.750000   564.750000   144.500000   72.000000
# ...

# %%
c_year_all[3]
# 2019년도 대비 2022년 평균 점포 밀집도가 약 44% 감소한 군집임
# 평균 ln(sales)는 2019년도에 비해 0.4%p 감소
# -> 평균 점포 밀집도 및 평균 ln(sales)가 적게 감소한 군집임
# Out:
# cluster                        3            3            3            3
# sales         count    15.000000    20.000000    51.000000    17.000000
#               mean     26.710354    26.354118    25.563221    26.310977
#               std       0.591535     0.598230     0.864269     0.590599
#               min      25.679136    25.237733    23.561924    25.329271
#               25%      26.280445    25.967591    25.030039    25.778708
#               50%      26.799339    26.236748    25.601265    26.433522
#               75%      27.169460    26.946064    26.062340    26.792758
#               max      27.601204    27.312835    27.257173    27.220229
# store density count    15.000000    20.000000    51.000000    17.000000
#               mean   2597.383333  2400.362500  1648.000000  1441.019608
#               std     644.285782   647.939886   641.333347   499.789157
#               min    1880.500000  1685.000000   943.500000   943.666667
# ...
