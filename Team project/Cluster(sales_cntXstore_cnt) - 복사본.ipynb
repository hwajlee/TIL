# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
hangjungdong_sales = pd.read_csv('C:\TIL\Team project/행정동별_DB.csv')

# %%
hangjungdong_sales
# Out:
#       Unnamed: 0    행정동_코드  기준_년_코드  기준_분기_코드   분기당_매출_금액  분기당_매출_건수  점포수  \
# 0              0  11110515     2019         1  4675790356     237169  305
# 1              1  11110515     2019         2  4826602913     288328  280
# 2              2  11110515     2019         3  5054226611     294296  306
# 3              3  11110515     2019         4  5259740378     276138  296
# 4              4  11110515     2020         1  3831066308     201207  280
# ...          ...       ...      ...       ...         ...        ...  ...
# 5996        5996  11740700     2021         3  5268468421     286646  284
# 5997        5997  11740700     2021         4  5055977570     246028  267
# 5998        5998  11740700     2022         1  4458386133     224449  161
# 5999        5999  11740700     2022         2  5527855722     266771  163
# 6000        6000  11740700     2022         3  5740889583     271136  161
#
#       면적 (k㎡)   건당_매출액  점포_밀집도
# 0        2.57  23701.0   118.0
# 1        2.57  20963.6   109.0
# 2        2.57  21133.0   119.0
# 3        2.57  21326.2   116.0
# 4        2.57  19221.6   109.0
# ...       ...      ...     ...
# 5996     1.56  15627.4   182.0
# 5997     1.56  16716.6   171.0
# 5998     1.56  15356.6   104.0
# 5999     1.56  16121.6   105.0
# 6000     1.56  15895.8   104.0
#
# [6001 rows x 10 columns]

# %%
# 4분기 제외 (2022YQ3까지만 있는 관계로 매년 ~Q3 데이터까지만 활용)
hangjungdong_sales.drop(hangjungdong_sales[hangjungdong_sales['기준_분기_코드'] ==4].index)
# Out:
#       Unnamed: 0    행정동_코드  기준_년_코드  기준_분기_코드   분기당_매출_금액  분기당_매출_건수  점포수  \
# 0              0  11110515     2019         1  4675790356     237169  305
# 1              1  11110515     2019         2  4826602913     288328  280
# 2              2  11110515     2019         3  5054226611     294296  306
# 4              4  11110515     2020         1  3831066308     201207  280
# 5              5  11110515     2020         2  4730870452     263071  283
# ...          ...       ...      ...       ...         ...        ...  ...
# 5995        5995  11740700     2021         2  5516378578     286822  291
# 5996        5996  11740700     2021         3  5268468421     286646  284
# 5998        5998  11740700     2022         1  4458386133     224449  161
# 5999        5999  11740700     2022         2  5527855722     266771  163
# 6000        6000  11740700     2022         3  5740889583     271136  161
#
#       면적 (k㎡)   건당_매출액  점포_밀집도
# 0        2.57  23701.0   118.0
# 1        2.57  20963.6   109.0
# 2        2.57  21133.0   119.0
# 4        2.57  19221.6   109.0
# 5        2.57  20319.6   110.0
# ...       ...      ...     ...
# 5995     1.56  17206.8   186.0
# 5996     1.56  15627.4   182.0
# 5998     1.56  15356.6   104.0
# 5999     1.56  16121.6   105.0
# 6000     1.56  15895.8   104.0
#
# [4801 rows x 10 columns]

# %%
# df 결측치 확인
hangjungdong_sales.isna().sum()
# Out:
# Unnamed: 0    0
# 행정동_코드        0
# 기준_년_코드       0
# 기준_분기_코드      0
# 분기당_매출_금액     0
# 분기당_매출_건수     0
# 점포수           0
# 면적 (k㎡)       0
# 건당_매출액        0
# 점포_밀집도        0
# dtype: int64

# %%
hangjungdong_sales_ = hangjungdong_sales.groupby(['행정동_코드','기준_년_코드']).agg({'분기당_매출_금액':sum, '분기당_매출_건수':sum,'점포수' : np.average, "면적 (k㎡)":max,"점포_밀집도":np.average }).reset_index()

# %%
hangjungdong_sales_
# Out:
#         행정동_코드  기준_년_코드     분기당_매출_금액  분기당_매출_건수          점포수  면적 (k㎡)  \
# 0     11110515     2019   19816360258    1095931   296.750000     2.57
# 1     11110515     2020   18089079791     935274   283.000000     2.57
# 2     11110515     2021   25083059412    1297556   285.250000     2.57
# 3     11110515     2022   25734795800    1345940   157.666667     2.57
# 4     11110530     2019  309346012700   13513402  2355.250000     1.23
# ...        ...      ...           ...        ...          ...      ...
# 1596  11740685     2022   87037961471    4886490   705.333333     1.61
# 1597  11740700     2019   25367953678    1215827   320.750000     1.56
# 1598  11740700     2020   23735340525    1236250   317.500000     1.56
# 1599  11740700     2021   20667046819    1064359   286.500000     1.56
# 1600  11740700     2022   15727131438     762356   161.666667     1.56
#
#            점포_밀집도
# 0      115.500000
# 1      110.000000
# 2      111.000000
# 3       61.000000
# 4     1914.500000
# ...           ...
# 1596   438.000000
# 1597   206.000000
# 1598   203.500000
# 1599   183.250000
# 1600   104.333333
#
# [1601 rows x 7 columns]

# %%
hangjungdong_sales_['건당_매출_금액'] = hangjungdong_sales_['분기당_매출_금액'] / hangjungdong_sales_['분기당_매출_건수']
hangjungdong_sales_['건당_매출_금액'] = hangjungdong_sales_['건당_매출_금액'].round(1)

# %%
hangjungdong_sales_['ln_건당_매출_금액'] = np.log(hangjungdong_sales_['건당_매출_금액'])

# %%
hangjungdong_sales_
# Out:
#         행정동_코드  기준_년_코드     분기당_매출_금액  분기당_매출_건수          점포수  면적 (k㎡)  \
# 0     11110515     2019   19816360258    1095931   296.750000     2.57
# 1     11110515     2020   18089079791     935274   283.000000     2.57
# 2     11110515     2021   25083059412    1297556   285.250000     2.57
# 3     11110515     2022   25734795800    1345940   157.666667     2.57
# 4     11110530     2019  309346012700   13513402  2355.250000     1.23
# ...        ...      ...           ...        ...          ...      ...
# 1596  11740685     2022   87037961471    4886490   705.333333     1.61
# 1597  11740700     2019   25367953678    1215827   320.750000     1.56
# 1598  11740700     2020   23735340525    1236250   317.500000     1.56
# 1599  11740700     2021   20667046819    1064359   286.500000     1.56
# 1600  11740700     2022   15727131438     762356   161.666667     1.56
#
#            점포_밀집도  건당_매출_금액  ln_건당_매출_금액
# 0      115.500000   18081.8     9.802661
# 1      110.000000   19340.9     9.869977
# 2      111.000000   19331.0     9.869465
# 3       61.000000   19120.3     9.858506
# 4     1914.500000   22891.8    10.038534
# ...           ...       ...          ...
# 1596   438.000000   17812.0     9.787628
# 1597   206.000000   20864.8     9.945819
# 1598   203.500000   19199.5     9.862640
# 1599   183.250000   19417.4     9.873925
# 1600   104.333333   20629.6     9.934482
#
# [1601 rows x 9 columns]

# %%
for_cluster = hangjungdong_sales_[[ '행정동_코드', '기준_년_코드','분기당_매출_건수', '점포수']]

# %%
for_cluster.rename(columns={'행정동_코드':'code',
                                    '기준_년_코드':'year',
                                    '분기당_매출_건수':'sales cnt',
                                    '점포수': 'store cnt'}, inplace=True)
# Out:
# C:\Users\이화정\AppData\Local\Temp\ipykernel_20932\1096864430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for_cluster.rename(columns={'행정동_코드':'code',

# %%
for_cluster
# Out:
#           code  year  sales cnt    store cnt
# 0     11110515  2019    1095931   296.750000
# 1     11110515  2020     935274   283.000000
# 2     11110515  2021    1297556   285.250000
# 3     11110515  2022    1345940   157.666667
# 4     11110530  2019   13513402  2355.250000
# ...        ...   ...        ...          ...
# 1596  11740685  2022    4886490   705.333333
# 1597  11740700  2019    1215827   320.750000
# 1598  11740700  2020    1236250   317.500000
# 1599  11740700  2021    1064359   286.500000
# 1600  11740700  2022     762356   161.666667
#
# [1601 rows x 4 columns]

# %%
for_cluster19 = for_cluster[for_cluster['year'] == 2019]
for_cluster20 = for_cluster[for_cluster['year'] == 2020]
for_cluster21 = for_cluster[for_cluster['year'] == 2021]
for_cluster22 = for_cluster[for_cluster['year'] == 2022]

# %%
# 데이터 정규화(Min-Max)
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
scaler.fit(for_cluster19[['sales cnt','store cnt']])
scaler.fit(for_cluster20[['sales cnt','store cnt']])
scaler.fit(for_cluster21[['sales cnt','store cnt']])
scaler.fit(for_cluster22[['sales cnt','store cnt']])
# Out:
# MinMaxScaler()

# %%
set_19_sc = scaler.transform(for_cluster19[['sales cnt','store cnt']])
set_20_sc = scaler.transform(for_cluster20[['sales cnt','store cnt']])
set_21_sc = scaler.transform(for_cluster21[['sales cnt','store cnt']])
set_22_sc = scaler.transform(for_cluster22[['sales cnt','store cnt']])

# %%
# !pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in c:\programdata\anaconda3\lib\site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from yellowbrick) (3.5.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from yellowbrick) (1.9.1)
# Requirement already satisfied: cycler>=0.10.0 in c:\programdata\anaconda3\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from yellowbrick) (1.0.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from yellowbrick) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)

# %%
# 적절한 군집수 찾기 1. The Elbow method
from yellowbrick.cluster import KElbowVisualizer

# %%
# 2019년
model = KMeans(random_state=0)
visualizer = KElbowVisualizer(model, k = (1,10))
plt.subplot(2, 1, 1)
visualizer.fit(set_19_sc.reshape(-1,1))

# 2020년
model = KMeans(random_state=0)
visualizer = KElbowVisualizer(model, k = (1,10))
plt.subplot(2, 1, 2)
visualizer.fit(set_20_sc.reshape(-1,1))
# Out:
# KElbowVisualizer(ax=<AxesSubplot:>,
#                  estimator=KMeans(n_clusters=9, random_state=0), k=(1, 10))

# %%
# 2021년
model = KMeans(random_state=0)
visualizer = KElbowVisualizer(model, k = (1,10))
plt.subplot(2, 1, 1)
visualizer.fit(set_21_sc.reshape(-1,1))

# 2022년
model = KMeans(random_state=0)
visualizer = KElbowVisualizer(model, k = (1,10))
plt.subplot(2, 1, 2)
visualizer.fit(set_22_sc.reshape(-1,1))
# Out:
# KElbowVisualizer(ax=<AxesSubplot:>,
#                  estimator=KMeans(n_clusters=9, random_state=0), k=(1, 10))

# %%
# 적절한 군집수 찾기 2. The Silhouette method
### 여러개의 클러스터링 갯수를 List로 입력 받아 각각의 실루엣 계수를 면적으로 시각화한 함수 작성
def visualize_silhouette(cluster_lists, X_features): 
    
    # from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math
    
    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)
    
    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)
    
    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):
        
        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)
        
        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)
        
        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
        
        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()
            
            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i
            
            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10
            
        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
# 2019년
# cluster 개수를 3개, 4개, 5개, 6개 일때의 클러스터별 실루엣 계수 평균값을 시각화 
visualize_silhouette([3, 4, 5, 6], set_19_sc)

# %%
# 2020년
# cluster 개수를 3개, 4개, 5개, 6개 일때의 클러스터별 실루엣 계수 평균값을 시각화 
visualize_silhouette([3, 4, 5, 6], set_20_sc)

# %%
# 2021년
# cluster 개수를 3개, 4개, 5개, 6개 일때의 클러스터별 실루엣 계수 평균값을 시각화 
visualize_silhouette([3, 4, 5, 6], set_21_sc)

# %%
# 2022년
# cluster 개수를 3개, 4개, 5개, 6개 일때의 클러스터별 실루엣 계수 평균값을 시각화 
visualize_silhouette([3, 4, 5, 6], set_22_sc)

# %%
# 군집 수 적용
km19 = KMeans(n_clusters=3, init='k-means++', random_state=119).fit(set_19_sc)
km20 = KMeans(n_clusters=3, init='k-means++', random_state=119).fit(set_20_sc)
km21 = KMeans(n_clusters=3, init='k-means++', random_state=119).fit(set_21_sc)
km22 = KMeans(n_clusters=3, init='k-means++', random_state=119).fit(set_22_sc)

# %%
for_cluster19['cluster'] = km19.predict(set_19_sc)
for_cluster20['cluster'] = km20.predict(set_20_sc)
for_cluster21['cluster'] = km22.predict(set_21_sc)
for_cluster22['cluster'] = km22.predict(set_22_sc)
# Out:
# C:\Users\이화정\AppData\Local\Temp\ipykernel_20932\268568640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for_cluster19['cluster'] = km19.predict(set_19_sc)
# C:\Users\이화정\AppData\Local\Temp\ipykernel_20932\268568640.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for_cluster20['cluster'] = km20.predict(set_20_sc)
# C:\Users\이화정\AppData\Local\Temp\ipykernel_20932\268568640.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for_cluster21['cluster'] = km22.predict(set_21_sc)
# C:\Users\이화정\AppData\Local\Temp\ipykernel_20932\268568640.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for_cluster22['cluster'] = km22.predict(set_22_sc)

# %%
print(f'2019년도 군집:\n', for_cluster19['cluster'].value_counts())
print(f'\n2020년도 군집:\n', for_cluster20['cluster'].value_counts())
print(f'\n2021년도 군집:\n', for_cluster21['cluster'].value_counts())
print(f'\n2022년도 군집:\n', for_cluster22['cluster'].value_counts())
# Out:
# 2019년도 군집:
#  0    160
# 3    140
# 2     86
# 1     15
# Name: cluster, dtype: int64
#
# 2020년도 군집:
#  1    167
# 3    126
# 0     88
# 2     19
# Name: cluster, dtype: int64
#
# 2021년도 군집:
#  1    177
# 0    113
# 2     71
# 3     39
# Name: cluster, dtype: int64
#
# 2022년도 군집:
#  1    177
# 2    148
# 0     64
# 3     11
# Name: cluster, dtype: int64

# %%
# 19, 20년 군집 번호 변경 
new_for_cluster19 = for_cluster19.copy()
new_for_cluster20 = for_cluster20.copy()

# %%
# 군집 변경 함수
# 2019년 
## 0번 -> 1번 
## 1번 -> 3번 
## 2번 -> 0번 
## 3번 ->2번 

def change_num_2019(num) :
        if num == 0:
            return 1
        elif num == 1:
            return 3
        elif num == 2:
            return 0
        elif num == 3:
            return 2
        
# 2020년 
## 1번 -> 2번 
## 2번 -> 3번 
## 3번 -> 1번 

def change_num_2020(num) :
        if num == 1:
            return 2
        elif num == 2 :
            return 3
        elif num == 3:
            return 1
        else : return num

# %%
new_for_cluster19['cluster'] = new_for_cluster19['cluster'].apply(change_num_2019 )
new_for_cluster20['cluster'] = new_for_cluster20['cluster'].apply(change_num_2020 )

# %%
c_19 = for_cluster19.drop(['year', 'code'], axis=1)
c_20 = for_cluster20.drop(['year', 'code'], axis=1)
c_21 = for_cluster21.drop(['year', 'code'], axis=1)
c_22 = for_cluster22.drop(['year', 'code'], axis=1)

# %%
# (x, y) = (건당 매출 금액, 점포 밀집도) 시각화 
# 2019년
sct_2019 = sns.scatterplot(x='sales cnt', y='store cnt', hue='cluster', data=c_19)
sct_2019.set(title = "2019Y")
# Out:
# [Text(0.5, 1.0, '2019Y')]

# %%
# 2020년
sns.scatterplot(x='sales cnt', y='store cnt', hue='cluster', data=c_20)
# Out:
# <AxesSubplot:xlabel='sales cnt', ylabel='store cnt'>

# %%
# 2021년
sns.scatterplot(x='sales cnt', y='store cnt', hue='cluster', data=c_21)
# Out:
# <AxesSubplot:xlabel='sales cnt', ylabel='store cnt'>

# %%
# 2022년
sns.scatterplot(x='sales cnt', y='store cnt', hue='cluster', data=c_22)
# Out:
# <AxesSubplot:xlabel='sales cnt', ylabel='store cnt'>

# %%
# 변수간 산점도 시각화 (pairplot: 데이터에 들어 있는 각 컬럼(열)들의 모든 상관 관계를 출력)
# 2019Y
sns.pairplot(c_19, hue = 'cluster')
plt.show()

# %%
# 2020Y
sns.pairplot(c_20, hue = 'cluster')
plt.show()

# %%
# 2021Y
sns.pairplot(c_21, hue = 'cluster')
plt.show()

# %%
# 2022Y 
sns.pairplot(c_22, hue = 'cluster')
plt.show()
